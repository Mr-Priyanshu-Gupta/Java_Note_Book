# %% [markdown]
# JAVA is Installed

# %%
# !apt-get install openjdk-11-jdk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libxcomposite1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-11-jdk-headless openjdk-11-jre openjdk-11-jre-headless
#   session-migration x11-utils
# Suggested packages:
#   libxt-doc openjdk-11-demo openjdk-11-source visualvm libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libxcomposite1 libxt-dev libxtst6 libxxf86dga1
# ...

# %% [markdown]
# FIrst JAVA Code

# %%
# %%writefile HelloWorld.java
# public class HelloWorld {
#     public static void main(String[] args) {
#         System.out.println("Hello from Java on Colab!");
#     }
# }
# Out:
# Writing HelloWorld.java

# %% [markdown]
# Running JAVA

# %%
# !javac HelloWorld.java
# !java HelloWorld
# Out:
# Hello from Java on Colab!

# %% [markdown]
# Starting with java

# %% [markdown]
# Simple Out-Put

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruit = "apple";
#     System.out.println(fruit);
#   }
# }
# Out:
# Writing Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple

# %% [markdown]
# Simple Array convertion

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruit [] = {"apple","Banana","Coconut","Orange"};
#     System.out.println(fruit);
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# [Ljava.lang.String;@7ad041f3

# %% [markdown]
# in array [arr] = {0,1,2,3}
# sequence start from 0 to n-1
#
# and it print like array[num]

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruit [] = {"apple","Banana","Coconut","Orange"};
#     System.out.println(fruit[2]);
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1

# fruit[0] = apple
# Out:
# apple

# %%
# !javac Array1.java
# !java Array1

# fruit[1] = Banana
# Out:
# Banana

# %%
# !javac Array1.java
# !java Array1

# fruit[2] = Coconut
# Out:
# Coconut

# %%
# !javac Array1.java
# !java Array1

# fruit[3] = Orange
# Out:
# Orange

# %% [markdown]
# Array.length
# it is use to get how many elements an array have

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#     int number_of_fruits = fruits.length;
#
#     System.out.println(number_of_fruits);
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# 4

# %% [markdown]
# Using For Loop with an Array

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#     //int number_of_fruits = fruits.length;
#
#     for (int i = 0 ; i < fruits.length; i++){
#     System.out.println(fruits[0]);
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple
# apple
# apple
# apple

# %% [markdown]
# Traversing in array with simple for-loop

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#     //int number_of_fruits = fruits.length;
#
#     for (int i = 0 ; i < fruits.length; i++){
#     System.out.println(fruits[i]);
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple
# Banana
# Coconut
# Orange

# %% [markdown]
# Traversing in a single line

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#     //int number_of_fruits = fruits.length;
#
#     for (int i = 0 ; i < fruits.length; i++){
#     System.out.print(fruits[i]+ " ");
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple Banana Coconut Orange

# %% [markdown]
# way to to change array secuence

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#     //fruits[0] = "Pineapple";
#     //fruits[1] = "Pineapple" ;
#     //fruits[2] = "Pineapple" ;
#     //fruits[3] = "Pineapple" ;
#     //int number_of_fruits = fruits.length;
#
#     for (int i = 0 ; i < fruits.length; i++){
#     System.out.print(fruits[i]+ " ");
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# Pineapple Banana Coconut Orange

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple Pineapple Coconut Orange

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple Banana Pineapple Orange

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple Banana Coconut Pineapple

# %% [markdown]
# Enhenced for lop also known as for-each-loop

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#
#
#     for (String fruit : fruits){
#     System.out.print(fruit+ " ");
#     }
#   }
# }
# Out:
# Writing Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple Banana Coconut Orange

# %%
# %%writefile Array1.java
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"apple","Banana","Coconut","Orange"};
#
#
#
#     for (String fruit : fruits){
#     System.out.println(fruit);
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# apple
# Banana
# Coconut
# Orange

# %% [markdown]
# Sort Array

# %%
# %%writefile Array1.java
# import java.util.Arrays;
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"Apple","Orange","Coconut","Banana"};
#
#     Arrays.sort(fruits);
#
#     for (String fruit : fruits){
#     System.out.println(fruit);
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# Apple
# Banana
# Coconut
# Orange

# %% [markdown]
# Fill Array

# %%
# %%writefile Array1.java
# import java.util.Arrays;
# public class Array1 {
#   public static void main(String[] args) {
#     String fruits [] = {"Apple","Orange","Coconut","Banana"};
#
#     //Arrays.sort(fruits);
#       Arrays.fill(fruits,"Pineapple");
#
#     for (String fruit : fruits){
#     System.out.println(fruit);
#     }
#   }
# }
# Out:
# Overwriting Array1.java

# %%
# !javac Array1.java
# !java Array1
# Out:
# Pineapple
# Pineapple
# Pineapple
# Pineapple
